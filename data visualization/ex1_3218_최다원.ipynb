# %%
import pandas as pd

# %%
ac = pd.read_csv('../data/ex01.csv', encoding="utf-8")
ac.head()
# Out:
#        timestamp  LinearAccelerometerSensor
# 0  1584624517761                   1.500325
# 1  1584624517776                   0.135825
# 2  1584624517823                   0.590677
# 3  1584624517882                   1.022730
# 4  1584624517942                   1.341890

# %%
ac.columns
# Out:
# Index(['timestamp', 'LinearAccelerometerSensor'], dtype='object')

# %%
ac.columns[0]
# Out:
# 'timestamp'

# %%
ac.rename(columns={ac.columns[0]:'시간', ac.columns[1]:'선형가속도'}, inplace=True)
ac.head()
# Out:
#               시간     선형가속도
# 0  1584624517761  1.500325
# 1  1584624517776  0.135825
# 2  1584624517823  0.590677
# 3  1584624517882  1.022730
# 4  1584624517942  1.341890

# %%
ac.describe()
# Out:
#                  시간       선형가속도
# count  3.270000e+02  327.000000
# mean   1.584625e+12   15.073747
# std    5.633368e+03   15.936749
# min    1.584625e+12    0.135825
# 25%    1.584625e+12    3.326796
# 50%    1.584625e+12    7.482398
# 75%    1.584625e+12   22.021996
# max    1.584625e+12   60.978464

# %%
ac.sort_values(by='선형가속도', ascending=False).head()
# Out:
#                 시간      선형가속도
# 82   1584624522592  60.978464
# 65   1584624521585  60.694222
# 119  1584624524798  60.517172
# 112  1584624524380  59.294273
# 36   1584624519849  57.989684

# %%
ac.sort_values(by='선형가속도', ascending=True).head()
# Out:
#                 시간     선형가속도
# 1    1584624517776  0.135825
# 325  1584624537071  0.329284
# 326  1584624537130  0.351247
# 321  1584624536832  0.443954
# 323  1584624536951  0.484512

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

if platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

# %%
plt.plot(ac['시간'], ac['선형가속도'])
plt.show()

# %%
plt.plot(ac['시간'], ac['선형가속도'])
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.grid()
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ac['시간'], ac['선형가속도'], color='green', linestyle='dashed', marker='o')
plt.grid()
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()
